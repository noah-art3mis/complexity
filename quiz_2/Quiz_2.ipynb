# %% [markdown]
# # Quiz 2
#
# LIS MASc
# Engaging Complexity
#
# Access this notebook on [GitHub](https://github.com/noah-art3mis/complexity/blob/main/quiz_2/Quiz_2.ipynb)
# PDF generated using [nbconvert](https://nbconvert.readthedocs.io/en/latest/index.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("fivethirtyeight")
plt.rcParams["figure.dpi"] = 300

# %% [markdown]
# ## 1

# %% [markdown]
# ### (a)

# %%
def population(t):
    return 73.2 / (6.1 + 5.9 * np.exp(-0.02 * t))

print(f'Year 2200: around {population(200):.2f} billion humans')
print(f'Year 2300: around {population(300):.2f} billion humans')
# Out:
# Year 2200: around 11.79 billion humans
# Year 2300: around 11.97 billion humans

# %% [markdown]
# ### (b)

# %%
years = np.linspace(0, 501)
plt.plot(years, population(years));

# %% [markdown]
# ### (c)

# %% [markdown]
# The population approaches as 12 billion as time goes on.

# %% [markdown]
# ## 2

# %% [markdown]
# ### (a)

# %%
def mass_remaining_after_radioactive_decay(time_in_days):
    return 13 * np.exp(-0.015 * time_in_days)

# %%
mass_remaining_after_radioactive_decay(time_in_days=0)
# Out:
# np.float64(13.0)

# %%
mass_remaining_after_radioactive_decay(time_in_days=45)
# Out:
# np.float64(6.61903346789814)

# %% [markdown]
# ### (b)

# %%
def mg_remaining(time_in_hours):
    return 50 * np.exp(-0.2 * time_in_hours)

# %%
for i in range(5):
    print(f'{i}h: {mg_remaining(i):.2f}mg remaining')
# Out:
# 0h: 50.00mg remaining
# 1h: 40.94mg remaining
# 2h: 33.52mg remaining
# 3h: 27.44mg remaining
# 4h: 22.47mg remaining

# %% [markdown]
# If it starts at 50mg, the half life should be when the function returns 25mg, which would be between 3h and 4h.

# %% [markdown]
# $$D(t) = 50e^{-0.2t}$$
#
# Assuming $D(t)$ is 25mg, we get:
#
# $25 = 50e^{-0.2t}$
#
# Solving for $t$:
#
# $1/2 = e^{-0.2t}$
#
# $\ln(0.5) = -0.2t$
#
# $t = \frac{\ln(0.5)}{-0.2}$

# %%
np.log(0.5) / -0.2
# Out:
# np.float64(3.465735902799726)

# %% [markdown]
# ## 3

# %% [markdown]
# ### (a)

# %% [markdown]
# $$t = \frac{\log(N/50)}{log(2)}$$

# %% [markdown]
# $N = 1,000,000$
#
# $t = \frac{\log(1,000,000/50)}{log(2)}$

# %% [markdown]
# $t = \frac{\log(20,000)}{log(2)}$
#
# By the change of base formula
#
# $\frac{\log(20,000)}{log(2)} = log_2(20,000)$
#
# $t = log_2(20,000)$

# %%
np.log2(20_000)
# Out:
# np.float64(14.287712379549449)

# %% [markdown]
# ### (b)

# %%
def time_to_double_investment(compound_rate):
    return np.log(2) / compound_rate

# %%
time_to_double_investment(0.06)
# Out:
# np.float64(11.552453009332423)

# %%
time_to_double_investment(0.07)
# Out:
# np.float64(9.902102579427789)

# %%
time_to_double_investment(0.08)
# Out:
# np.float64(8.664339756999317)

# %% [markdown]
# ### (c)

# %% [markdown]
# $t = -k \ln (1 - \frac{C}{C_0})$
#
# $k = 0.25$
#
# $C = 0.9 C_0$
#
# $t = -0.25 \ln (1 - \frac{C}{C_0})$
#
# $t = -0.25 \ln (1 - \frac{0.9 C_0}{C_0})$
#
# $t = -0.25 \ln (1 - 0.9)$
#
# $t = -0.25 \ln (0.1)$

# %%
-0.25 * np.log(0.1)
# Out:
# np.float64(0.5756462732485114)

# %% [markdown]
# ## 4

# %% [markdown]
# ### (a)

# %% [markdown]
# $$log_{10}(P) = log_{10}(c) − k log_{10}(W)$$

# %% [markdown]
# $log_{10}(P) = log_{10}(c/W^k)$

# %% [markdown]
# $P = c/W^k$

# %% [markdown]
# ### (b)

# %% [markdown]
# $k = 2.1$
#
# $c = 8000$
#
# $W = 2$
#
# $P = c/W^k$
#
# $P = 8000/2^{2.1}$

# %%
8000/2**2.1
# Out:
# 1866.065983073615

# %%
8000/10**2.1
# Out:
# 63.546258777942505
